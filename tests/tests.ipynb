# %%
# Imports
# !pip install pandas
# !pip install requests
import pandas, requests, json

# %%
# Load data
with open('houston_zips.json', 'r') as f:
  houston_zips = json.load(f)
simple_shape = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "coordinates": [
          [
            [
              -111.96758627137338,
              33.503838484175375
            ],
            [
              -111.97904771486695,
              33.45763200126959
            ],
            [
              -111.92019150029336,
              33.46783861669121
            ],
            [
              -111.89234012644222,
              33.493246873827815
            ],
            [
              -111.92681699571692,
              33.5269288495591
            ],
            [
              -111.96758627137338,
              33.503838484175375
            ]
          ]
        ],
        "type": "Polygon"
      }
    }
  ]
}

# %%
# Queries
queries = [
  {"buffer":0,"shape":json.dumps(houston_zips)}, # Zips in Houston
  {"buffer": 1, "shape": json.dumps(simple_shape), "geometries": True},
  {"buffer": 4, "sites": [{"lat":33, "lon":-112}]}, # A single set of coordinates
  {"buffer": 4, "sites": [{"lat":33, "lon":-112}, {"lat":34, "lon":-114}]}, # Two or more coordinates
  {"buffer": 0, "fips": ["482012301001","482012302002", "482012302003"], "scale":"blockgroup"}, # FIPS
  {"buffer": 0, "fips": "DE", "scale": "blockgroup"}, # One state, blockgroup level results
  {"buffer": 0, "fips": "DE", "scale": "county"}, # One state, county level results
  {"buffer": 0, "fips": ["DE", "RI"], "scale": "county"} # Two states, county level results
]

# %%
# Execute data queries
import time

for q in queries:
  time.sleep(5)
  try:
    url = "http://localhost:55001/data" #"https://ejamapi-84652557241.us-central1.run.app/data"
    response = requests.post(url, json=q)
    # Load response
    df = pandas.DataFrame.from_dict(response.json())
    display(df)
  except:
    print("error with ", q)
# Out:
#                                            EJAM Report  \
# 0    <a href="https://ejamapi-84652557241.us-centra...
# 1    <a href="https://ejamapi-84652557241.us-centra...
# 2    <a href="https://ejamapi-84652557241.us-centra...
# 3    <a href="https://ejamapi-84652557241.us-centra...
# 4    <a href="https://ejamapi-84652557241.us-centra...
# ..                                                 ...
# 166  <a href="https://ejamapi-84652557241.us-centra...
# 167  <a href="https://ejamapi-84652557241.us-centra...
# 168  <a href="https://ejamapi-84652557241.us-centra...
# 169  <a href="https://ejamapi-84652557241.us-centra...
# 170  <a href="https://ejamapi-84652557241.us-centra...
#
#                                           EJSCREEN Map  ejam_uniq_id  valid  \
# 0    <a href="https://pedp-ejscreen.azurewebsites.n...             1   True
# 1    <a href="https://pedp-ejscreen.azurewebsites.n...             2   True
# 2    <a href="https://pedp-ejscreen.azurewebsites.n...             3   True
# 3    <a href="https://pedp-ejscreen.azurewebsites.n...             4   True
# 4    <a href="https://pedp-ejscreen.azurewebsites.n...             5   True
# ..                                                 ...           ...    ...
# 166  <a href="https://pedp-ejscreen.azurewebsites.n...           167   True
# 167  <a href="https://pedp-ejscreen.azurewebsites.n...           168   True
# 168  <a href="https://pedp-ejscreen.azurewebsites.n...           169   True
# 169  <a href="https://pedp-ejscreen.azurewebsites.n...           170   True
# 170  <a href="https://pedp-ejscreen.azurewebsites.n...           171   True
#
#           pop  ST statename  in_how_many_states  REGION  \
# 0     54313.0  TX     Texas                   1       6
# 1     18612.9  TX     Texas                   1       6
# 2     49315.1  TX     Texas                   1       6
# 3     41562.4  TX     Texas                   1       6
# 4     36309.8  TX     Texas                   1       6
# ..        ...  ..       ...                 ...     ...
# 166   23183.2  TX     Texas                   1       6
# 167   91208.8  TX     Texas                   1       6
# 168  121952.5  TX     Texas                   1       6
# 169   90624.5  TX     Texas                   1       6
# 170    4498.6  TX     Texas                   1       6
#
#      ratio.to.avg.Demog.Index  ...  state.EJ.DISPARITY.rsei.supp  \
# 0                      1.5036  ...                      131.4918
# 1                      0.6552  ...                       65.8810
# 2                      1.4375  ...                      111.8982
# 3                      1.6712  ...                      126.8409
# 4                      1.6456  ...                      157.7305
# ..                        ...  ...                           ...
# 166                    0.9401  ...                       71.5685
# 167                    1.0028  ...                       47.9565
# 168                    1.4356  ...                       91.3777
# 169                    0.7673  ...                       69.9486
# 170                    0.8837  ...                       36.2437
#
#      state.EJ.DISPARITY.traffic.score.supp  \
# 0                                  59.8899
# 1                                  34.7455
# 2                                  90.6335
# 3                                 105.2680
# 4                                 167.0281
# ..                                     ...
# 166                                78.1392
# 167                                34.1685
# 168                                69.4557
# 169                                38.6110
# 170                                37.7249
#
#      state.EJ.DISPARITY.pctpre1960.supp  \
# 0                               36.4022
# 1                                9.3588
# 2                                6.1945
# 3                                7.2429
# 4                               80.0305
# ..                                  ...
# 166                             18.6346
# 167                              5.8282
# 168                              9.3677
# 169                              9.9433
# 170                              8.8025
#
#      state.EJ.DISPARITY.proximity.npl.supp  \
# 0                                  56.5742
# 1                                  19.6931
# 2                                 120.7731
# 3                                   0.0000
# 4                                  54.0806
# ..                                     ...
# 166                                22.5674
# 167                                 0.0000
# 168                                 0.0000
# 169                                57.9152
# 170                                37.8195
#
#      state.EJ.DISPARITY.proximity.rmp.supp  \
# 0                                  51.7501
# 1                                  65.1348
# 2                                 104.6664
# 3                                  82.6721
# 4                                 126.7383
# ..                                     ...
# 166                                62.4799
# 167                                21.7366
# 168                                69.4174
# 169                                33.2652
# 170                                35.5658
#
#      state.EJ.DISPARITY.proximity.tsdf.supp  state.EJ.DISPARITY.ust.supp  \
# 0                                   92.7255                      54.9181
# 1                                   64.8415                      15.2261
# 2                                  122.9995                      71.8546
# 3                                  108.8946                      80.9880
# 4                                  151.1585                     142.9151
# ..                                      ...                          ...
# 166                                 81.0358                      63.4533
# 167                                 33.6285                      18.7730
# 168                                 41.5139                      57.0196
# 169                                 45.2239                      39.8186
# 170                                 38.5128                      23.6986
#
#      state.EJ.DISPARITY.proximity.npdes.supp  \
# 0                                   115.6136
# 1                                    65.7204
# 2                                   101.6271
# 3                                    98.7387
# 4                                   148.0119
# ..                                       ...
# 166                                  65.7672
# 167                                  48.3814
# 168                                  76.3733
# 169                                  67.8430
# 170                                  28.6486
#
#      state.EJ.DISPARITY.drinking.supp  area_sqmi
# 0                             58.3160    46.6848
# 1                              0.0000     9.3043
# 2                              6.8387    14.8426
# 3                             44.5195    14.6538
# 4                              0.0000     8.1379
# ..                                ...        ...
# 166                           78.9731    10.7538
# 167                           26.7071    34.3282
# 168                           25.8124    27.1924
# 169                           26.0171    38.2225
# 170                            0.0000     0.5127
#
# [171 rows x 454 columns]
#                                          EJAM Report  \
# 0  <a href="https://ejamapi-84652557241.us-centra...
#
#                                         EJSCREEN Map  ejam_uniq_id  valid  \
# 0  <a href="https://pedp-ejscreen.azurewebsites.n...             1   True
#
#         pop  ST statename  in_how_many_states  REGION  \
# 0  123399.6  AZ   Arizona                   1       9
#
#    ratio.to.avg.Demog.Index  ...  state.EJ.DISPARITY.traffic.score.supp  \
# 0                    0.8283  ...                                87.3294
#
#    state.EJ.DISPARITY.pctpre1960.supp  state.EJ.DISPARITY.proximity.npl.supp  \
# 0                             72.9272                               102.3956
#
#    state.EJ.DISPARITY.proximity.rmp.supp  \
# 0                                68.2126
#
#    state.EJ.DISPARITY.proximity.tsdf.supp  state.EJ.DISPARITY.ust.supp  \
# 0                                  83.985                      63.9312
#
#    state.EJ.DISPARITY.proximity.npdes.supp  state.EJ.DISPARITY.drinking.supp  \
# 0                                  99.9936                           37.2937
#
#    area_sqmi                                           geometry
# 0    32.4743  {'type': 'Polygon', 'coordinates': [[[-111.967...
#
# [1 rows x 455 columns]
#                                          EJAM Report  \
# 0  <a href="https://ejamapi-84652557241.us-centra...
#
#                                         EJSCREEN Map  ejam_uniq_id  valid  \
# 0  <a href="https://pedp-ejscreen.azurewebsites.n...             1   True
#
#   invalid_msg      pop  lon  lat  ST statename  ...  \
# 0              13841.5 -112   33  AZ   Arizona  ...
#
#    state.EJ.DISPARITY.rsei.supp  state.EJ.DISPARITY.traffic.score.supp  \
# 0                       18.0333                                20.7834
#
#    state.EJ.DISPARITY.pctpre1960.supp  state.EJ.DISPARITY.proximity.npl.supp  \
# 0                             16.4923                                 3.1568
#
#    state.EJ.DISPARITY.proximity.rmp.supp  \
# 0                                 1.8941
#
#    state.EJ.DISPARITY.proximity.tsdf.supp  state.EJ.DISPARITY.ust.supp  \
# 0                                  1.1838                      29.8227
#
#    state.EJ.DISPARITY.proximity.npdes.supp  state.EJ.DISPARITY.drinking.supp  \
# 0                                  96.8384                           102.757
#
#    area_sqmi
# 0    50.2655
#
# [1 rows x 457 columns]
#                                          EJAM Report  \
# 0  <a href="https://ejamapi-84652557241.us-centra...
# 1  <a href="https://ejamapi-84652557241.us-centra...
#
#                                         EJSCREEN Map  ejam_uniq_id  valid  \
# 0  <a href="https://pedp-ejscreen.azurewebsites.n...             1   True
# 1  <a href="https://pedp-ejscreen.azurewebsites.n...             2   True
#
#   invalid_msg      pop  lon  lat  ST statename  ...  \
# 0              13841.5 -112   33  AZ   Arizona  ...
# 1                194.6 -114   34  AZ   Arizona  ...
#
#    state.EJ.DISPARITY.rsei.supp  state.EJ.DISPARITY.traffic.score.supp  \
# 0                       18.0333                                20.7834
# 1                        0.0000                                 2.5030
#
#    state.EJ.DISPARITY.pctpre1960.supp  state.EJ.DISPARITY.proximity.npl.supp  \
# 0                             16.4923                                 3.1568
# 1                            154.8858                                 0.0000
#
#    state.EJ.DISPARITY.proximity.rmp.supp  \
# 0                                 1.8941
# 1                                 0.0000
#
#    state.EJ.DISPARITY.proximity.tsdf.supp  state.EJ.DISPARITY.ust.supp  \
# 0                                  1.1838                      29.8227
# 1                                 50.8580                      73.9753
#
#    state.EJ.DISPARITY.proximity.npdes.supp  state.EJ.DISPARITY.drinking.supp  \
# 0                                  96.8384                          102.7570
# 1                                  43.9228                          155.7571
#
#    area_sqmi
# 0    50.2655
# 1    50.2655
#
# [2 rows x 457 columns]
#                                          EJAM Report  \
# 0  <a href="https://ejamapi-84652557241.us-centra...
# 1  <a href="https://ejamapi-84652557241.us-centra...
# 2  <a href="https://ejamapi-84652557241.us-centra...
#
#                                         EJSCREEN Map  ejam_uniq_id  valid  \
# 0  <a href="https://pedp-ejscreen.azurewebsites.n...  482012301001   True
# 1  <a href="https://pedp-ejscreen.azurewebsites.n...  482012302002   True
# 2  <a href="https://pedp-ejscreen.azurewebsites.n...  482012302003   True
#
#   invalid_msg   pop  ST statename  REGION  ratio.to.avg.Demog.Index  ...  \
# 0              1380  TX     Texas       6                    2.1126  ...
# 1               176  TX     Texas       6                    2.1047  ...
# 2              1448  TX     Texas       6                    2.1900  ...
#
#    state.EJ.DISPARITY.rsei.supp  state.EJ.DISPARITY.traffic.score.supp  \
# 0                      215.4872                               224.7555
# 1                      281.4480                               272.4656
# 2                      229.1651                               216.9755
#
#    state.EJ.DISPARITY.pctpre1960.supp  state.EJ.DISPARITY.proximity.npl.supp  \
# 0                            208.5360                               227.0726
# 1                            272.4656                               290.4304
# 2                            209.6617                               234.0410
#
#    state.EJ.DISPARITY.proximity.rmp.supp  \
# 0                               125.1216
# 1                               149.7064
# 2                               124.3343
#
#    state.EJ.DISPARITY.proximity.tsdf.supp  state.EJ.DISPARITY.ust.supp  \
# 0                                208.5360                     192.3166
# 1                                275.4598                     227.5537
# 2                                226.7272                     199.9100
#
#    state.EJ.DISPARITY.proximity.npdes.supp  state.EJ.DISPARITY.drinking.supp  \
# 0                                 187.6824                                 0
# 1                                 251.5067                                 0
# 2                                 204.7858                                 0
#
#    area_sqmi
# 0     0.5265
# 1     0.3791
# 2     0.6477
#
# [3 rows x 453 columns]
#                                            EJAM Report  \
# 0    <a href="https://ejamapi-84652557241.us-centra...
# 1    <a href="https://ejamapi-84652557241.us-centra...
# 2    <a href="https://ejamapi-84652557241.us-centra...
# 3    <a href="https://ejamapi-84652557241.us-centra...
# 4    <a href="https://ejamapi-84652557241.us-centra...
# ..                                                 ...
# 701  <a href="https://ejamapi-84652557241.us-centra...
# 702  <a href="https://ejamapi-84652557241.us-centra...
# 703  <a href="https://ejamapi-84652557241.us-centra...
# 704  <a href="https://ejamapi-84652557241.us-centra...
# 705  <a href="https://ejamapi-84652557241.us-centra...
#
#                                           EJSCREEN Map  ejam_uniq_id  valid  \
# 0    <a href="https://pedp-ejscreen.azurewebsites.n...  100010401001   True
# 1    <a href="https://pedp-ejscreen.azurewebsites.n...  100010401002   True
# 2    <a href="https://pedp-ejscreen.azurewebsites.n...  100010401003   True
# 3    <a href="https://pedp-ejscreen.azurewebsites.n...  100010401004   True
# 4    <a href="https://pedp-ejscreen.azurewebsites.n...  100010402011   True
# ..                                                 ...           ...    ...
# 701  <a href="https://pedp-ejscreen.azurewebsites.n...  100050519001   True
# 702  <a href="https://pedp-ejscreen.azurewebsites.n...  100050519002   True
# 703  <a href="https://pedp-ejscreen.azurewebsites.n...  100050519003   True
# 704  <a href="https://pedp-ejscreen.azurewebsites.n...  100059800001  False
# 705  <a href="https://pedp-ejscreen.azurewebsites.n...  100059900000  False
#
#                          invalid_msg   pop  ST statename  REGION  \
# 0                                     1730  DE  Delaware       3
# 1                                     2315  DE  Delaware       3
# 2                                     1902  DE  Delaware       3
# 3                                     1396  DE  Delaware       3
# 4                                     2778  DE  Delaware       3
# ..                               ...   ...  ..       ...     ...
# 701                                   1330  DE  Delaware       3
# 702                                   1691  DE  Delaware       3
# 703                                   1562  DE  Delaware       3
# 704  blocks found but zero residents     0  DE  Delaware       3
# 705  blocks found but zero residents     0  DE  Delaware       3
#
#      ratio.to.avg.Demog.Index  ...  state.EJ.DISPARITY.proximity.tsdf.supp  \
# 0                      0.7284  ...                                 15.1866
# 1                      0.7966  ...                                 15.1068
# 2                      0.5005  ...                                  0.0000
# 3                      0.3264  ...                                  0.0000
# 4                      0.7586  ...                                  0.0000
# ..                        ...  ...                                     ...
# 701                    0.7270  ...                                 57.4057
# 702                    0.8141  ...                                 66.9257
# 703                    0.6244  ...                                 62.7086
# 704                       NaN  ...                                     NaN
# 705                       NaN  ...                                     NaN
#
#      state.EJ.DISPARITY.ust.supp  state.EJ.DISPARITY.proximity.npdes.supp  \
# 0                         0.0000                                   0.0000
# 1                        33.2350                                   0.0000
# 2                         0.0000                                   0.0000
# 3                         0.0000                                   0.0000
# 4                         0.0000                                   0.0000
# ..                           ...                                      ...
# 701                       0.0000                                  32.0796
# 702                     101.2466                                  22.3086
# 703                      75.9104                                  26.4036
# 704                          NaN                                      NaN
# 705                          NaN                                      NaN
#
#      state.EJ.DISPARITY.drinking.supp  area_sqmi  ratio.to.avg.lowlifex  \
# 0                                 0.0    16.0276                    NaN
# 1                                 NaN    12.9632                    NaN
# 2                                 NaN     9.2209                    NaN
# 3                                 NaN     9.9529                    NaN
# 4                                 0.0     3.1208                 1.0030
# ..                                ...        ...                    ...
# 701                               NaN    26.3366                 1.0922
# 702                               0.0     2.7916                 1.0922
# 703                               0.0     4.4039                 1.0922
# 704                               NaN     5.1255                    NaN
# 705                               NaN     0.0000                    NaN
#
#      ratio.to.state.avg.lowlifex  lowlifex  pctile.lowlifex  \
# 0                            NaN       NaN              NaN
# 1                            NaN       NaN              NaN
# 2                            NaN       NaN              NaN
# 3                            NaN       NaN              NaN
# 4                         0.9781    0.1959             52.0
# ..                           ...       ...              ...
# 701                       1.0651    0.2133             69.0
# 702                       1.0651    0.2133             69.0
# 703                       1.0651    0.2133             69.0
# 704                          NaN       NaN              NaN
# 705                          NaN       NaN              NaN
#
#      state.pctile.lowlifex
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                     40.0
# ..                     ...
# 701                   67.0
# 702                   67.0
# 703                   67.0
# 704                    NaN
# 705                    NaN
#
# [706 rows x 453 columns]
#                                          EJAM Report  \
# 0  <a href="https://ejamapi-84652557241.us-centra...
# 1  <a href="https://ejamapi-84652557241.us-centra...
# 2  <a href="https://ejamapi-84652557241.us-centra...
#
#                                         EJSCREEN Map ejam_uniq_id  valid  \
# 0  <a href="https://pedp-ejscreen.azurewebsites.n...        10001   True
# 1  <a href="https://pedp-ejscreen.azurewebsites.n...        10003   True
# 2  <a href="https://pedp-ejscreen.azurewebsites.n...        10005   True
#
#   invalid_msg     pop  ST statename  REGION  ratio.to.avg.Demog.Index  ...  \
# 0              182400  DE  Delaware       3                    1.0056  ...
# 1              570567  DE  Delaware       3                    0.9519  ...
# 2              240668  DE  Delaware       3                    0.7750  ...
#
#    state.EJ.DISPARITY.rsei.supp  state.EJ.DISPARITY.traffic.score.supp  \
# 0                       38.5244                                58.0604
# 1                       90.4826                                90.2368
# 2                       33.9036                                23.0925
#
#    state.EJ.DISPARITY.pctpre1960.supp  state.EJ.DISPARITY.proximity.npl.supp  \
# 0                             69.7450                                55.8801
# 1                             73.4902                                85.1709
# 2                             57.1725                                38.0055
#
#    state.EJ.DISPARITY.proximity.rmp.supp  \
# 0                                28.5269
# 1                                83.1845
# 2                                50.6670
#
#    state.EJ.DISPARITY.proximity.tsdf.supp  state.EJ.DISPARITY.ust.supp  \
# 0                                 41.9320                      66.9203
# 1                                 90.9198                      75.5866
# 2                                 30.3860                      56.4092
#
#    state.EJ.DISPARITY.proximity.npdes.supp  state.EJ.DISPARITY.drinking.supp  \
# 0                                  15.5517                           16.4766
# 1                                  85.8882                           47.4166
# 2                                  49.2791                           10.2229
#
#    area_sqmi
# 0   586.0610
# 1   426.3367
# 2   936.1455
#
# [3 rows x 453 columns]
#                                          EJAM Report  \
# 0  <a href="https://ejamapi-84652557241.us-centra...
# 1  <a href="https://ejamapi-84652557241.us-centra...
# 2  <a href="https://ejamapi-84652557241.us-centra...
# 3  <a href="https://ejamapi-84652557241.us-centra...
# 4  <a href="https://ejamapi-84652557241.us-centra...
# 5  <a href="https://ejamapi-84652557241.us-centra...
# 6  <a href="https://ejamapi-84652557241.us-centra...
# 7  <a href="https://ejamapi-84652557241.us-centra...
#
#                                         EJSCREEN Map ejam_uniq_id  valid  \
# 0  <a href="https://pedp-ejscreen.azurewebsites.n...        10001   True
# 1  <a href="https://pedp-ejscreen.azurewebsites.n...        10003   True
# 2  <a href="https://pedp-ejscreen.azurewebsites.n...        10005   True
# 3  <a href="https://pedp-ejscreen.azurewebsites.n...        44001   True
# 4  <a href="https://pedp-ejscreen.azurewebsites.n...        44003   True
# 5  <a href="https://pedp-ejscreen.azurewebsites.n...        44005   True
# 6  <a href="https://pedp-ejscreen.azurewebsites.n...        44007   True
# 7  <a href="https://pedp-ejscreen.azurewebsites.n...        44009   True
#
#   invalid_msg     pop  ST     statename  REGION  ratio.to.avg.Demog.Index  \
# 0              182400  DE      Delaware       3                    1.0056
# 1              570567  DE      Delaware       3                    0.9519
# 2              240668  DE      Delaware       3                    0.7750
# 3               50658  RI  Rhode Island       1                    0.3412
# 4              170168  RI  Rhode Island       1                    0.5157
# 5               85442  RI  Rhode Island       1                    0.4836
# 6              657984  RI  Rhode Island       1                    1.0101
# 7              129998  RI  Rhode Island       1                    0.4224
#
#    ...  state.EJ.DISPARITY.rsei.supp  state.EJ.DISPARITY.traffic.score.supp  \
# 0  ...                       38.5244                                58.0604
# 1  ...                       90.4826                                90.2368
# 2  ...                       33.9036                                23.0925
# 3  ...                       26.8323                                25.2977
# 4  ...                       17.4188                                45.3942
# 5  ...                       16.5074                                18.3886
# 6  ...                      106.2236                               107.4662
# 7  ...                       30.4643                                 9.1685
#
#    state.EJ.DISPARITY.pctpre1960.supp  state.EJ.DISPARITY.proximity.npl.supp  \
# 0                             69.7450                                55.8801
# 1                             73.4902                                85.1709
# 2                             57.1725                                38.0055
# 3                             40.9070                                 5.4196
# 4                             49.3086                                30.8717
# 5                             41.1419                                63.8807
# 6                             87.3474                                95.7495
# 7                             24.7772                                39.5665
#
#    state.EJ.DISPARITY.proximity.rmp.supp  \
# 0                                28.5269
# 1                                83.1845
# 2                                50.6670
# 3                                28.1295
# 4                                56.9729
# 5                                14.8522
# 6                                90.6274
# 7                                20.6565
#
#    state.EJ.DISPARITY.proximity.tsdf.supp  state.EJ.DISPARITY.ust.supp  \
# 0                                 41.9320                      66.9203
# 1                                 90.9198                      75.5866
# 2                                 30.3860                      56.4092
# 3                                 25.9250                      34.5514
# 4                                 47.3934                      60.5631
# 5                                 17.5891                      41.1616
# 6                                105.7177                      95.1674
# 7                                  8.6317                      24.9007
#
#    state.EJ.DISPARITY.proximity.npdes.supp  state.EJ.DISPARITY.drinking.supp  \
# 0                                  15.5517                           16.4766
# 1                                  85.8882                           47.4166
# 2                                  49.2791                           10.2229
# 3                                  30.6751                            0.0000
# 4                                  47.0029                            4.9947
# 5                                  15.0673                           12.7030
# 6                                  98.9208                            2.5652
# 7                                  20.8730                           31.8537
#
#    area_sqmi
# 0   586.0610
# 1   426.3367
# 2   936.1455
# 3    24.1317
# 4   168.5679
# 5   102.4305
# 6   409.4816
# 7   329.2786
#
# [8 rows x 453 columns]

# %%
# Test reports
queries = [
  #{"buffer":0,"shape":json.dumps(houston_zips)}, # Zips in Houston # too long a request?
  {"buffer": 1, "shape": json.dumps(simple_shape)},
  {"buffer": 4, "lat":33, "lon":-112}, # A single set of coordinates
  {"buffer": 0, "fips": ["482012301001","482012302002", "482012302003"]}, # FIPS - will only do first in list
  {"buffer": 0, "fips": "48201230100"}, # Census Tract
  {"buffer": 0, "fips": "06037"}, # County
  {"buffer": 0, "fips": "44"} # Single state FIPS
]

# %%
# Report link constructor
import time

for q in queries:
  time.sleep(5)
  try:
    url = "http://localhost:55001/report" #"https://ejamapi-84652557241.us-central1.run.app/report" # 
    response = requests.get(url, params=q)
    print(response.url)
    print(response.text)
  except:
    print("error with ", q)
# Out:
# http://localhost:55001/report?buffer=1&shape=%7B%22type%22%3A+%22FeatureCollection%22%2C+%22features%22%3A+%5B%7B%22type%22%3A+%22Feature%22%2C+%22properties%22%3A+%7B%7D%2C+%22geometry%22%3A+%7B%22coordinates%22%3A+%5B%5B%5B-111.96758627137338%2C+33.503838484175375%5D%2C+%5B-111.97904771486695%2C+33.45763200126959%5D%2C+%5B-111.92019150029336%2C+33.46783861669121%5D%2C+%5B-111.89234012644222%2C+33.493246873827815%5D%2C+%5B-111.92681699571692%2C+33.5269288495591%5D%2C+%5B-111.96758627137338%2C+33.503838484175375%5D%5D%5D%2C+%22type%22%3A+%22Polygon%22%7D%7D%5D%7D
# http://localhost:55001/report?buffer=4&lat=33&lon=-112
# http://localhost:55001/report?buffer=0&fips=482012301001&fips=482012302002&fips=482012302003
# http://localhost:55001/report?buffer=0&fips=44
